# %% [markdown]
# ## **Tugas Besar Pemrosesan Citra Digital**
#
# **Klasifikasi Pneumonia dan Tuberculosis Menggunakan DenseNet-121
# berdasarkan Citra X-Ray**
#
# Achmad Fahriza - 1301213006
# Kemal Crisannaufal - 1301213133
# Pravitya Lintang Insani - 1301213204

# %%
#Import Modul
import os
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from keras.applications.densenet import DenseNet121
from keras.models import Model
from keras.layers import GlobalAveragePooling2D, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import imagehash
import seaborn as sns

# %%
#Fungsi untuk Contrast Stretching
def contrast_stretching(img):
  in_min = np.percentile(img, 5)
  in_max = np.percentile(img, 95)
  out_min, out_max = img.min(), img.max()
  img_contrast = (img - in_min) * ((out_max - out_min) / (in_max - in_min)) + out_min
  img_contrast = np.clip(img_contrast, out_min, out_max)
  return img_contrast

# %%
#Fungsi untuk Median Filtering
def median_filtering(img):
    img = cv2.medianBlur(img, 3)
    return img

# %%
#Fungsi untuk Load Data
#Resize, normalisasi, median filtering, contrast stretching
def load_image(image_path):
    img = Image.open(image_path)
    #Resize gambar 224 x 224
    img = img.resize((224, 224))
    img_array = np.array(img)
    #Normalisasi Citra
    img_array = img_array.astype('float32') / 255.0
    #Median Filtering
    img_array = median_filtering(img_array)
    #Contrast Stretching
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    img_array = contrast_stretching(img_array)
    return img_array

# %%
def load_image_wo_preprocessing(image_path):
    img = Image.open(image_path)
    #Resize gambar 224 x 224
    img = img.resize((224, 224))
    img_array = np.array(img)
    #Normalisasi Citra
    img_array = img_array.astype('float32') / 255.0
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    return img_array

# %% [markdown]
# #### **Load Data**
#
# Data di-load dan digabungkan antara data Tuberculosis dengan data Pneumonia dan paru-paru normal. Pada data Pneuomina dan normal data telah dibagi menjadi data train, data validation, dan data test, sedangkan pada data Tuberculosis data hanya terdiri dari sebuah folder berisi citra x-ray tuberculosis (tanpa pemisahan data). Oleh karena itu data Tuberculosis dilakukan pemisahan data di awal untuk digabungkan dengan data Pneumonia dan Normal.

# %%
#Hash untuk cek duplikat
def load_and_hash_image(image_path):
    with Image.open(image_path) as img:
        return str(imagehash.average_hash(img))

# %% [markdown]
# #### **Load Data Tuberculosis**

# %%
#Load Data Tuberculosis
train_dir = r'D:\PCD\Data'

categories = ['Tuberculosis']

data = []
labels = []
hashes = {}
duplicates = []
sample_data = []

i = 0
for category in categories:
    path = os.path.join(train_dir, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        img_hash = load_and_hash_image(img_path)

        if img_hash in hashes:
            duplicates.append((img_path, hashes[img_hash]))
            print("Duplikat:", img_path, "-", hashes[img_hash])
        else:
            hashes[img_hash] = img_path
            image = load_image(img_path)
            data.append(image)
            labels.append(category)

            if i < 10:
                image = load_image_wo_preprocessing(img_path)
                sample_data.append(image)
            i += 1
# Out:
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-244.png - D:\PCD\Data\Tuberculosis\Tuberculosis-243.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-348.png - D:\PCD\Data\Tuberculosis\Tuberculosis-346.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-405.png - D:\PCD\Data\Tuberculosis\Tuberculosis-386.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-430.png - D:\PCD\Data\Tuberculosis\Tuberculosis-378.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-469.png - D:\PCD\Data\Tuberculosis\Tuberculosis-467.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-470.png - D:\PCD\Data\Tuberculosis\Tuberculosis-467.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-471.png - D:\PCD\Data\Tuberculosis\Tuberculosis-396.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-510.png - D:\PCD\Data\Tuberculosis\Tuberculosis-509.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-571.png - D:\PCD\Data\Tuberculosis\Tuberculosis-566.png
# Duplikat: D:\PCD\Data\Tuberculosis\Tuberculosis-582.png - D:\PCD\Data\Tuberculosis\Tuberculosis-579.png

# %%
#Sample Data TBC Tanpa Preprocessing
plt.figure(figsize=(15, 30))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.imshow(sample_data[i])
    plt.title("Sample" + str(i+1))
    plt.axis('off')
plt.show()

# %%
#Sample Data TBC dengan Preprocessing
plt.figure(figsize=(15, 30))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.imshow(data[i])
    plt.title("Sample" + str(i+1))
    plt.axis('off')
plt.show()

# %%
#Split data menjadi data train, data validation, dan data test
data_train, data_val_test, labels_train, labels_val_test = train_test_split(data, labels, test_size=0.25, random_state=42)
data_val, data_test, labels_val, labels_test = train_test_split(data_val_test, labels_val_test, test_size=0.5, random_state=42)

# %% [markdown]
# #### **Load Data Pneumonia dan Normal**

# %%
#Load Data Train Normal dan Pneumonia
train_dir = r'D:\PCD\Data'

categories = ['Normal', 'Pneumonia']

data = []
labels = []
sample_data = []

i = 0
for category in categories:
    path = os.path.join(train_dir, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        img_hash = load_and_hash_image(img_path)

        if img_hash in hashes:
            duplicates.append((img_path, hashes[img_hash]))
            print("Duplikat:", img_path, "-", hashes[img_hash])
        else:
            hashes[img_hash] = img_path
            image = load_image(img_path)
            data.append(image)
            labels.append(category)

            if i < 10:
                image = load_image_wo_preprocessing(img_path)
                sample_data.append(image)
            i += 1

#Gabungkan data train yang baru di load dengan data sebelumnya (data TBC)
data_train.extend(data)
labels_train.extend(labels)
# Out:
# Duplikat: D:\PCD\Data\Normal\IM-0300-0001.jpeg - D:\PCD\Data\Normal\IM-0187-0001.jpeg
# Duplikat: D:\PCD\Data\Normal\IM-0320-0001.jpeg - D:\PCD\Data\Normal\IM-0160-0001.jpeg
# Duplikat: D:\PCD\Data\Normal\IM-0329-0001.jpeg - D:\PCD\Data\Normal\IM-0298-0001.jpeg
# Duplikat: D:\PCD\Data\Normal\IM-0332-0001.jpeg - D:\PCD\Data\Normal\IM-0327-0001.jpeg
# Duplikat: D:\PCD\Data\Normal\IM-0388-0001.jpeg - D:\PCD\Data\Normal\IM-0276-0001.jpeg
# Duplikat: D:\PCD\Data\Normal\IM-
jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person657_virus_1240.jpeg - D:\PCD\Data\Pneumonia\person618_virus_1189.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person667_virus_1252.jpeg - D:\PCD\Data\Pneumonia\person603_virus_1164.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person66_bacteria_326.jpeg - D:\PCD\Data\Pneumonia\person258_bacteria_1216.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person679_virus_1270.jpeg - D:\PCD\Data\Normal\NORMAL2-IM-0496-0001.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person682_virus_1273.jpeg - D:\PCD\Data\Normal\IM-0229-0001.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person684_virus_1275.jpeg - D:\PCD\Data\Pneumonia\person629_bacteria_2507.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person688_virus_1282.jpeg - D:\PCD\Data\Pneumonia\person688_virus_1281.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person705_virus_1303.jpeg - D:\PCD\Data\Pneumonia\person332_bacteria_1535.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person731_virus_1352.jpeg - D:\PCD\Data\Normal\IM-0500-0001.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person742_virus_1365.jpeg - D:\PCD\Data\Pneumonia\person321_bacteria_1487.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person759_bacteria_2663.jpeg - D:\PCD\Data\Pneumonia\person359_bacteria_1645.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person759_virus_1387.jpeg - D:\PCD\Data\Pneumonia\person1135_bacteria_3077.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person778_bacteria_2682.jpeg - D:\PCD\Data\Pneumonia\person458_bacteria_1950.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person789_bacteria_2694.jpeg - D:\PCD\Data\Pneumonia\person1344_bacteria_3421.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person833_virus_1469.jpeg - D:\PCD\Data\Normal\IM-0410-0001.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person834_bacteria_2748.jpeg - D:\PCD\Data\Pneumonia\person834_bacteria_2747.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person849_bacteria_2770.jpeg - D:\PCD\Data\Pneumonia\person1338_virus_2308.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person855_virus_1500.jpeg - D:\PCD\Data\Pneumonia\person1311_virus_2259.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person86_virus_159.jpeg - D:\PCD\Data\Normal\NORMAL2-IM-0496-0001.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person884_bacteria_2808.jpeg - D:\PCD\Data\Pneumonia\person1176_virus_1996.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person895_virus_1547.jpeg - D:\PCD\Data\Pneumonia\person1031_virus_1723.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person911_virus_1567.jpeg - D:\PCD\Data\Pneumonia\person1352_bacteria_3443.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person924_virus_1581.jpeg - D:\PCD\Data\Pneumonia\person1103_virus_1825.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person928_virus_1586.jpeg - D:\PCD\Data\Pneumonia\person59_bacteria_284.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person937_virus_1599.jpeg - D:\PCD\Data\Pneumonia\person605_bacteria_2466.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person978_virus_1653.jpeg - D:\PCD\Data\Pneumonia\person616_virus_1186.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person989_virus_1667.jpeg - D:\PCD\Data\Pneumonia\person23_bacteria_92.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person992_virus_1670.jpeg - D:\PCD\Data\Pneumonia\person735_bacteria_2638.jpeg
# Duplikat: D:\PCD\Data\Pneumonia\person997_bacteria_2926.jpeg - D:\PCD\Data\Pneumonia\person747_virus_1372.jpeg

# %%
#Sample Data Normal Tanpa Preprocessing
plt.figure(figsize=(15, 30))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.imshow(sample_data[i])
    plt.title("Sample" + str(i+1))
    plt.axis('off')
plt.show()

# %%
#Sample Data Normal Dengan Preprocessing
plt.figure(figsize=(15, 30))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.imshow(data[700+i])
    plt.title("Sample" + str(i+1))
    plt.axis('off')
plt.show()

# %%
#Load Data Validation
val_dir = r'D:\PCD\Data\val'

categories = ['Normal', 'Pneumonia']

data = []
labels = []

for category in categories:
    path = os.path.join(val_dir, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1715_bacteria_4532.jpeg - D:\PCD\Data\Pneumonia\person1236_virus_2096.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1717_bacteria_4536.jpeg - D:\PCD\Data\Pneumonia\person326_virus_675.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1719_bacteria_4541.jpeg - D:\PCD\Data\Pneumonia\person1306_bacteria_3272.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1728_bacteria_4556.jpeg - D:\PCD\Data\Pneumonia\person666_virus_1251.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1730_bacteria_4558.jpeg - D:\PCD\Data\Pneumonia\person1089_bacteria_3029.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1764_bacteria_4607.jpeg - D:\PCD\Data\Pneumonia\person337_bacteria_1563.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1819_bacteria_4677.jpeg - D:\PCD\Data\Normal\IM-0229-0001.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1880_bacteria_4765.jpeg - D:\PCD\Data\Pneumonia\person493_virus_999.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1918_bacteria_4825.jpeg - D:\PCD\Data\Pneumonia\person120_virus_226.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1927_bacteria_4836.jpeg - D:\PCD\Data\Pneumonia\person1310_bacteria_3300.jpeg
# Duplikat: D:\PCD\Data\val\Pneumonia\person1931_bacteria_4842.jpeg - D:\PCD\Data\Pneumonia\person131_virus_265.jpeg

# %%
#Load Data Test Normal dan Pneumonia
test_dir = r'D:\PCD\Data\test'

categories = ['Normal', 'Pneumonia']

data = []
labels = []

for category in categories:
    path = os.path.join(test_dir, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        img_hash = load_and_hash_image(img_path)

        if img_hash in hashes:
            duplicates.append((img_path, hashes[img_hash]))
            print("Duplikat:", img_path, "-", hashes[img_hash])
        else:
            hashes[img_hash] = img_path
            image = load_image(img_path)
            data.append(image)
            labels.append(category)

#Gabungkan data test yang baru di load dengan data test sebelumnya (data TBC)
data_test.extend(data)
labels_test.extend(labels)
# Out:
# Duplikat: D:\PCD\Data\test\Normal\IM-0059-0001.jpeg - D:\PCD\Data\val\Pneumonia\person1416_virus_2427.jpeg
# Duplikat: D:\PCD\Data\test\Normal\IM-0061-0001.jpeg - D:\PCD\Data\Normal\IM-0593-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\IM-0083-0001.jpeg - D:\PCD\Data\Normal\IM-0566-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\IM-0093-0001.jpeg - D:\PCD\Data\Normal\NORMAL2-IM-1035-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0013-0001.jpeg - D:\PCD\Data\Normal\NORMAL2-IM-0466-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0072-0001.jpeg - D:\PCD\Data\Normal\IM-0439-0001-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0092-0001.jpeg - D:\PCD\Data\val\Normal\NORMAL2-IM-1315-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0096-0001.jpeg - D:\PCD\Data\test\Normal\NORMAL2-IM-0095-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0112-0001.jpeg - D:\PCD\Data\test\Normal\IM-0070-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0173-0001-0002.jpeg - D:\PCD\Data\test\Normal\NORMAL2-IM-0173-0001-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0217-0001.jpeg - D:\PCD\Data\Pneumonia\person160_virus_316.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0246-0001-0002.jpeg - D:\PCD\Data\test\Normal\NORMAL2-IM-0246-0001-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0252-0001.jpeg - D:\PCD\Data\Normal\IM-0253-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0278-0001.jpeg - D:\PCD\Data\Normal\IM-0535-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0288-0001.jpeg - D:\PCD\Data\Pneumonia\person955_virus_1627.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0289-0001.jpeg - D:\PCD\Data\Pneumonia\person1182_virus_2017.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0305-0001.jpeg - D:\PCD\Data\Normal\IM-0491-0001-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0346-0001.jpeg - D:\PCD\Data\test\Normal\NORMAL2-IM-0304-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-0348-0001.jpeg - D:\PCD\Data\Normal\IM-0604-0001.jpeg
# Duplikat: D:\PCD\Data\test\Normal\NORMAL2-IM-
jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person78_bacteria_386.jpeg - D:\PCD\Data\Pneumonia\person361_bacteria_1651.jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person79_virus_148.jpeg - D:\PCD\Data\Normal\IM-0616-0001.jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person85_bacteria_424.jpeg - D:\PCD\Data\val\Pneumonia\person1480_bacteria_3859.jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person88_bacteria_439.jpeg - D:\PCD\Data\val\Pneumonia\person1398_virus_2401.jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person92_bacteria_450.jpeg - D:\PCD\Data\Pneumonia\person1206_bacteria_3158.jpeg
# Duplikat: D:\PCD\Data\test\Pneumonia\person96_bacteria_465.jpeg - D:\PCD\Data\Pneumonia\person278_virus_575.jpeg

# %% [markdown]
# #### **Data Train, Validation, dan Test Final**

# %%
#Ubah kelas menjadi numeric
numeric_label = {'Normal': 0, 'Pneumonia': 1, 'Tuberculosis': 2}

labels_train_numeric = np.array([numeric_label[label] for label in labels_train])
labels_val_numeric = np.array([numeric_label[label] for label in labels_val])
labels_test_numeric = np.array([numeric_label[label] for label in labels_test])

X_train = np.array(data_train)
X_val = np.array(data_val)
X_test = np.array(data_test)

# %% [markdown]
# #### **Data**

# %%
#Histogram Sebaran data Train
plt.figure(figsize=(8, 6))
plt.hist(labels_train_numeric, bins=np.arange(-0.5, 3, 1), rwidth=0.8)

plt.title('Histogram Data Train')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')

plt.xticks(np.arange(0, 3, 1))
plt.show()

# %% [markdown]
# Data train tidak seimbang dan didominasi oleh kelas Pneumonia. Oversampling SMOTE digunakan untuk menyeimbangkan kelas paru-paru normal dan tubercolis pada dataset.

# %%
#Penerapan SMOTE
smote = SMOTE()
X_train_oversampled, labels_oversampled = smote.fit_resample(X_train.reshape(len(X_train), 224*224*3), labels_train_numeric)
X_train_oversampled = X_train_oversampled.reshape(len(X_train_oversampled), 224, 224, 3)
# Out:
# c:\Users\pravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\pravi\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %%
#Histogram data train setelah penerapan SMOTE
plt.figure(figsize=(8, 6))
plt.hist(labels_oversampled, bins=np.arange(-0.5, 3, 1),  rwidth=0.8)

plt.title('Histogram Data Train Setelah Oversampling')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')

plt.xticks(np.arange(0, 3, 1))
plt.show()

# %%
#Jumlah data train setelah penerapan SMOTE
len(X_train_oversampled)
# Out:
# 8994

# %%
#Sample Hasil Dari Smote
plt.figure(figsize=(15, 30))
for i in range(15):
    plt.subplot(5, 5, i+1)
    plt.imshow(X_train_oversampled[np.random.randint(0, len(X_train_oversampled))])
    plt.title("Sample" + str(i+1))
    plt.axis('off')
plt.show()

# %%
classes = ['Normal', 'Pneumonia', 'Tuberculosis']

# %% [markdown]
# ####**Model**

# %%
#SKEMA 1
base_model = DenseNet121(weights='imagenet',
                         include_top=False,
                         input_shape=(224, 224, 3),
                         )

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
predictions = Dense(len(classes), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, labels_train_numeric, epochs=5, batch_size=32, validation_data=(X_val, labels_val_numeric))
# Out:
# Epoch 1/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.7711 - loss: 0.6604 - val_accuracy: 0.9470 - val_loss: 0.1393
# Epoch 2/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9020 - loss: 0.2462 - val_accuracy: 0.9615 - val_loss: 0.1184
# Epoch 3/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9147 - loss: 0.2183 - val_accuracy: 0.9595 - val_loss: 0.1183
# Epoch 4/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - accuracy: 0.9202 - loss: 0.1912 - val_accuracy: 0.9672 - val_loss: 0.0936
# Epoch 5/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9345 - loss: 0.1694 - val_accuracy: 0.9509 - val_loss: 0.1242

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'b', label='Training')
plt.plot(epochs, val_loss, 'r', label='Validasi')
plt.title('Loss Training dan Validasi')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, train_accuracy, 'b', label='Training')
plt.plot(epochs, val_accuracy, 'r', label='Validasi')
plt.title('Akurasi trainning dan validasi')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, labels_test_numeric)
print("Akurasi : ", accuracy * 100)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.7198 - loss: 0.7133
# Akurasi :  78.3410131931305

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test_numeric, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels= classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(labels_test_numeric, y_pred_classes))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.33      0.50       210
#            1       0.72      1.00      0.84       354
#            2       0.97      1.00      0.98        87
#
#     accuracy                           0.78       651
#    macro avg       0.89      0.78      0.77       651
# weighted avg       0.84      0.78      0.75       651

# %%
#SKEMA 2
base_model = DenseNet121(weights='imagenet',
                         include_top=False,
                         input_shape=(224, 224, 3),
                         )

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(len(classes), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train_oversampled, labels_oversampled, epochs=5, batch_size=32, validation_data=(X_val, labels_val_numeric))
# Out:
# Epoch 1/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 355s 1s/step - accuracy: 0.8269 - loss: 0.4517 - val_accuracy: 0.9412 - val_loss: 0.1531
# Epoch 2/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.9445 - loss: 0.1431 - val_accuracy: 0.9499 - val_loss: 0.1356
# Epoch 3/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 341s 1s/step - accuracy: 0.9485 - loss: 0.1327 - val_accuracy: 0.9566 - val_loss: 0.1031
# Epoch 4/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 338s 1s/step - accuracy: 0.9598 - loss: 0.1052 - val_accuracy: 0.9393 - val_loss: 0.1620
# Epoch 5/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.9579 - loss: 0.1102 - val_accuracy: 0.9576 - val_loss: 0.0954

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'b', label='Training')
plt.plot(epochs, val_loss, 'r', label='Validasi')
plt.title('Loss Training dan Validasi')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, train_accuracy, 'b', label='Training')
plt.plot(epochs, val_accuracy, 'r', label='Validasi')
plt.title('Akurasi trainning dan validasi')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, labels_test_numeric)
print("Akurasi : ", accuracy * 100)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8121 - loss: 0.5246
# Akurasi :  84.48540568351746

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test_numeric, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels= classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(labels_test_numeric, y_pred_classes))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.55      0.70       210
#            1       0.79      0.98      0.87       354
#            2       1.00      1.00      1.00        87
#
#     accuracy                           0.84       651
#    macro avg       0.91      0.84      0.86       651
# weighted avg       0.87      0.84      0.83       651

# %%
model.save('model8485.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#SKEMA 3
base_model = DenseNet121(weights='imagenet',
                         include_top=False,
                         input_shape=(224, 224, 3),
                         )

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
predictions = Dense(len(classes), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train_oversampled, labels_oversampled, epochs=5, batch_size=32, validation_data=(X_val, labels_val_numeric))
# Out:
# Epoch 1/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 423s 1s/step - accuracy: 0.8031 - loss: 0.4933 - val_accuracy: 0.9403 - val_loss: 0.1687
# Epoch 2/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 370s 1s/step - accuracy: 0.9205 - loss: 0.2017 - val_accuracy: 0.9509 - val_loss: 0.1283
# Epoch 3/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.9264 - loss: 0.1913 - val_accuracy: 0.9605 - val_loss: 0.1079
# Epoch 4/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 373s 1s/step - accuracy: 0.9261 - loss: 0.1861 - val_accuracy: 0.9258 - val_loss: 0.1755
# Epoch 5/5
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 371s 1s/step - accuracy: 0.9337 - loss: 0.1627 - val_accuracy: 0.8882 - val_loss: 0.2387

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'b', label='Training')
plt.plot(epochs, val_loss, 'r', label='Validasi')
plt.title('Loss Training dan Validasi')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, train_accuracy, 'b', label='Training')
plt.plot(epochs, val_accuracy, 'r', label='Validasi')
plt.title('Akurasi trainning dan validasi')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, labels_test_numeric)
print("Akurasi : ", accuracy * 100)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.9095 - loss: 0.2165
# Akurasi :  88.01843523979187

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test_numeric, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels= classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(labels_test_numeric, y_pred_classes))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       210
#            1       0.90      0.88      0.89       354
#            2       1.00      1.00      1.00        87
#
#     accuracy                           0.88       651
#    macro avg       0.90      0.90      0.90       651
# weighted avg       0.88      0.88      0.88       651

# %%
model.save('model88.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
